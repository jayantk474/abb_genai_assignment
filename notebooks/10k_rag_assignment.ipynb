# %% [markdown]
# # 10-K RAG Assignment (Colab)
# This notebook installs dependencies, builds the index, and runs the 13 questions.

# %%
# !pip -q install -r requirements.txt

# %% [markdown]
# ## Upload PDFs
# Upload the two PDFs into `data/` as:
# - `data/apple_2024_10k.pdf`
# - `data/tesla_2023_10k.pdf`

# %%
import os
os.makedirs('data', exist_ok=True)
print('Put PDFs in ./data')

# %%
# !python scripts/build_index.py --apple_pdf data/apple_2024_10k.pdf --tesla_pdf data/tesla_2023_10k.pdf --out_dir artifacts/index

# %%
# !python scripts/run_questions.py --index_dir artifacts/index --out_json outputs/answers.json

# %%
import json
print(open('outputs/answers.json','r',encoding='utf-8').read())
